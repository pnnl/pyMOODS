# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import figure
import plotly.express as px
import plotly.graph_objs as go
import plotly.io as pio
# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Dataframes

# %%
df1 = pd.read_csv("/Users/matt412/Downloads/2V-2O (1).csv")
df2 = pd.read_csv("/Users/matt412/Downloads/2V-4O (1).csv")
df3 = pd.read_csv("/Users/matt412/Downloads/4V-2O (1).csv")
df4 = pd.read_csv("/Users/matt412/Downloads/4V-4O (1).csv")

# %% [markdown]
# ## Scatter Plot - Objective Space - 2 Variables and 2 Objective functions

# %%
scatter = px.scatter(
            df1,
            x=df1["f1"],
            y=df1["f2"],
            labels={"df1[f1]": "f1", "df1[f2]": "f2"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## Scatter Plot - Decision Space - 2 Variables and 2 Objective functions

# %%
scatter_d = px.scatter(
            df1,
            x=df1["x1"],
            y=df1["x2"],
            labels={"df1[x1]": "x1", "df1[x2]": "x2"},
            title="Scatter Plot",
        )
scatter_d.show()

# %% [markdown]
# ## Parallel Coordinates - Objective Space - 2 Variables and 2 Objective functions

# %%
parallel = px.parallel_coordinates(
            df1,
            dimensions=["f1", "f2"],
            labels={"df1[f1]": "f1", "df1[f2]": "f2"},
            title="Parallel Coordinates",
        )
parallel.show()

# %% [markdown]
# ## Parallel Coordinates - Decision Space - 2 Variables and 2 Objective functions

# %%
parallel_d = px.parallel_coordinates(
            df1,
            dimensions=["x1", "x2"],
            labels={"df1[x1]": "x1", "df1[x2]": "x2"},
            title="Parallel Coordinates",
        )
parallel_d.show()

# %% [markdown]
# ## Heatmap - Objective Space - 2 Variables and 2 Objective functions

# %%
data1 = df1[["f1", "f2"]].values.tolist()
heatmap = px.imshow(
            data1,
            labels={"df1[f1]": "f1", "df1[f2]": "f2"},
            x=["f1", "f2"],
            color_continuous_scale=px.colors.sequential.Pinkyl,
            title="Heatmap",
        )
heatmap.show()

# %% [markdown]
# ## Heatmap - Decision Space - 2 Variables and 2 Objective functions

# %%
data2 = df1[["x1", "x2"]].values.tolist()
heatmap_d = px.imshow(
            data2,
            labels={"df1[x1]": "x1", "df1[x2]": "x2"},
            x=["x1", "x2"],
            color_continuous_scale=px.colors.sequential.Pinkyl,
            title="Heatmap",
        )
heatmap_d.show()

# %% [markdown]
# ## Scatter Plot - Objective Space - 2 Variables and 4 Objective functions

# %% [markdown]
# ### f1 vs f2

# %%
scatter = px.scatter(
            df2,
            x=df2["f1"],
            y=df2["f2"],
            labels={"df2[f1]": "f1", "df2[f2]": "f2"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ### f1 vs f3

# %%
scatter = px.scatter(
            df2,
            x=df2["f1"],
            y=df2["f3"],
            labels={"df2[f1]": "f1", "df2[f3]": "f3"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ### f1 vs f4

# %%
scatter = px.scatter(
            df2,
            x=df2["f1"],
            y=df2["f4"],
            labels={"df2[f1]": "f1", "df2[f4]": "f4"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ### f2 vs f3

# %%
scatter = px.scatter(
            df2,
            x=df2["f2"],
            y=df2["f3"],
            labels={"df2[f2]": "f2", "df2[f3]": "f3"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ### f2 vs f4

# %%
scatter = px.scatter(
            df2,
            x=df2["f2"],
            y=df2["f4"],
            labels={"df2[f2]": "f2", "df2[f4]": "f4"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ### f3 vs f4

# %%
scatter = px.scatter(
            df2,
            x=df2["f3"],
            y=df2["f4"],
            labels={"df2[f3]": "f3", "df2[f4]": "f4"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## Scatter Plot - Decision Space - 2 Variables and 4 Objective functions

# %%
scatter_d = px.scatter(
            df2,
            x=df2["x1"],
            y=df2["x2"],
            labels={"df2[x1]": "x1", "df2[x2]": "x2"},
            title="Scatter Plot",
        )
scatter_d.show()

# %% [markdown]
# ## Parallel Coordinates - Objective Space - 2 Variables and 4 Objective functions

# %%
parallel = px.parallel_coordinates(
            df2,
            dimensions=["f1", "f2", "f3", "f4"],
            labels={"df2[f1]": "f1", "df2[f2]": "f2", "df2[f3]": "f3", "df2[f4]": "f4"},
            title="Parallel Coordinates",
        )
parallel.show()

# %% [markdown]
# ## Parallel Coordinates - Decision Space - 2 Variables and 4 Objective functions

# %%
parallel_d = px.parallel_coordinates(
            df2,
            dimensions=["x1", "x2"],
            labels={"df2[x1]": "x1", "df2[x2]": "x2"},
            title="Parallel Coordinates",
        )
parallel_d.show()

# %% [markdown]
# ## Heatmap - Objective Space - 2 Variables and 4 Objective functions

# %%
data3 = df2[["f1", "f2", "f3", "f4"]].values.tolist()
heatmap = px.imshow(
            data3,
            labels={"df2[f1]": "f1", "df2[f2]": "f2", "df2[f3]": "f3", "df2[f4]": "f4"},
            x=["f1", "f2", "f3", "f4"],
            color_continuous_scale=px.colors.sequential.Pinkyl,
            title="Heatmap",
        )
heatmap.show()

# %% [markdown]
# ## Heatmap - Decision Space - 2 Variables and 4 Objective functions

# %%
data4 = df2[["x1", "x2"]].values.tolist()
heatmap_d = px.imshow(
            data4,
            labels={"df2[x1]": "x1", "df2[x2]": "x2"},
            x=["x1", "x2"],
            color_continuous_scale=px.colors.sequential.Pinkyl,
            title="Heatmap",
        )
heatmap_d.show()

# %% [markdown]
# ## Scatter Plot - Objective Space - 4 Variables and 2 Objective functions

# %%
scatter = px.scatter(
            df3,
            x=df3["f1"],
            y=df3["f2"],
            labels={"df3[f1]": "f1", "df3[f2]": "f2"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## Scatter Plot - Decision Space - 4 Variables and 2 Objective functions

# %%
scatter_d = px.scatter_3d(
            df3,
            x=df3["x1"],
            y=df3["x2"],
            z=df3["x3"],
            color=df3["x4"],
            labels={"df3[x1]": "x1", "df3[x2]": "x2", "df3[x3]": "x3", "df3[x4]": "x4"},
            title="Scatter Plot",
        )
scatter_d.show()
# Out:
# <div>                            <div id="64bcc3bc-f9b8-4a97-a618-014b426984a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64bcc3bc-f9b8-4a97-a618-014b426984a0")) {                    Plotly.newPlot(                        "64bcc3bc-f9b8-4a97-a618-014b426984a0",                        [{"hovertemplate":"x1=%{x}\u003cbr\u003ex2=%{y}\u003cbr\u003ex3=%{z}\u003cbr\u003ex4=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.0755833726983433,0.7900979243762923,0.8684452330625629,0.31486520078975,0.0115944769151913,0.5644985015267908,0.3371065472798781,0.5594416672355315,0.5202026858374076,0.5127206297347374,0.9729383763449414,0.8908106631243409,0.607949021511999,0.0818540900105948,0.2995060275113956,0.360406
# ...

# %% [markdown]
# ## Parallel Coordinates - Objective Space - 4 Variables and 2 Objective functions

# %%
parallel = px.parallel_coordinates(
            df3,
            dimensions=["f1", "f2"],
            labels={"df3[f1]": "f1", "df3[f2]": "f2"},
            title="Parallel Coordinates",
        )
parallel.show()

# %% [markdown]
# ## Parallel Coordinates - Decision Space - 4 Variables and 2 Objective functions

# %%
parallel_d = px.parallel_coordinates(
            df3,
            dimensions=["x1", "x2", "x3", "x4"],
            labels={"df3[x1]": "x1", "df3[x2]": "x2", "df3[x3]": "x3", "df3[x4]": "x4"},
            title="Parallel Coordinates",
        )
parallel_d.show()

# %% [markdown]
# ## Heatmap - Objective Space - 4 Variables and 2 Objective functions

# %%
data5 = df3[["f1", "f2"]].values.tolist()
heatmap = px.imshow(
            data5,
            labels={"df3[f1]": "f1", "df3[f2]": "f2"},
            x=["f1", "f2"],
            color_continuous_scale=px.colors.sequential.Pinkyl,
            title="Heatmap",
        )
heatmap.show()

# %% [markdown]
# ## Heatmap - Decision Space - 4 Variables and 2 Objective functions

# %%
data6 = df3[["x1", "x2", "x3", "x4"]].values.tolist()
heatmap_d = px.imshow(
            data6,
            labels={"df3[x1]": "x1", "df3[x2]": "x2", "df3[x3]": "x3", "df3[x4]": "x4"},
            x=["x1", "x2", "x3", "x4"],
            color_continuous_scale=px.colors.sequential.Pinkyl,
            title="Heatmap",
        )
heatmap_d.show()

# %% [markdown]
# ## Scatter Plot - Objective Space - 4 Variables and 4 Objective functions

# %% [markdown]
# ## f1 vs f2

# %%
scatter = px.scatter(
            df4,
            x=df4["f1"],
            y=df4["f2"],
            labels={"df4[f1]": "f1", "df4[f2]": "f2"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## f1 vs f3

# %%
scatter = px.scatter(
            df4,
            x=df4["f1"],
            y=df4["f3"],
            labels={"df4[f1]": "f1", "df4[f3]": "f3"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## f1 vs f4

# %%
scatter = px.scatter(
            df4,
            x=df4["f1"],
            y=df4["f4"],
            labels={"df4[f1]": "f1", "df4[f4]": "f4"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## f2 vs f3

# %%
scatter = px.scatter(
            df4,
            x=df4["f2"],
            y=df4["f3"],
            labels={"df4[f2]": "f2", "df4[f3]": "f3"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## f2 vs f4

# %%
scatter = px.scatter(
            df4,
            x=df4["f2"],
            y=df4["f4"],
            labels={"df4[f2]": "f2", "df4[f4]": "f4"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## f3 vs f4

# %%
scatter = px.scatter(
            df4,
            x=df4["f3"],
            y=df4["f4"],
            labels={"df4[f3]": "f3", "df4[f4]": "f4"},
            title="Scatter Plot",
        )
scatter.show()

# %% [markdown]
# ## Scatter Plot - Decision Space - 4 Variables and 4 Objective functions

# %%
scatter_d = px.scatter_3d(
            df4,
            x=df4["x1"],
            y=df4["x2"],
            z=df4["x3"],
            color=df4["x4"],
            labels={"df4[x1]": "x1", "df4[x2]": "x2", "df4[x3]": "x3", "df4[x4]": "x4"},
            title="Scatter Plot",
        )
scatter_d.show()
# Out:
# <div>                            <div id="b01c25fb-e2cd-4a1b-a578-43637105abd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b01c25fb-e2cd-4a1b-a578-43637105abd5")) {                    Plotly.newPlot(                        "b01c25fb-e2cd-4a1b-a578-43637105abd5",                        [{"hovertemplate":"x1=%{x}\u003cbr\u003ex2=%{y}\u003cbr\u003ex3=%{z}\u003cbr\u003ex4=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.0591046614594331,0.946204178591854,0.6453782869889201,0.991758270933971,0.1961418157008184,0.8372780007977106,0.7539256703107465,0.3420503388893573,0.9713124579287756,0.5230092083072158,0.5847407392137457,0.679580090930688,0.5424526629689668,0.9198078036225548,0.2845815014444296,0.656749
# ...

# %% [markdown]
# ## Parallel Coordinates - Objective Space - 4 Variables and 4 Objective functions

# %%
parallel = px.parallel_coordinates(
            df4,
            dimensions=["f1", "f2", "f3", "f4"],
            labels={"df4[f1]": "f1", "df4[f2]": "f2", "df4[f3]": "f3", "df4[f4]": "f4"},
            title="Parallel Coordinates",
        )
parallel.show()

# %% [markdown]
# ## Parallel Coordinates - Decision Space - 4 Variables and 4 Objective functions

# %%
parallel_d = px.parallel_coordinates(
            df4,
            dimensions=["x1", "x2", "x3", "x4"],
            labels={"df4[x1]": "x1", "df4[x2]": "x2", "df4[x3]": "x3", "df4[x4]": "x4"},
            title="Parallel Coordinates",
        )
parallel_d.show()

# %% [markdown]
# ## Heatmap - Objective Space - 4 Variables and 4 Objective functions

# %%
data7 = df4[["f1", "f2", "f3", "f4"]].values.tolist()
heatmap = px.imshow(
            data7,
            labels={"df4[f1]": "f1", "df4[f2]": "f2", "df4[f3]": "f3", "df4[f4]": "f4"},
            x=["f1", "f2", "f3", "f4"],
            color_continuous_scale=px.colors.sequential.Pinkyl,
            title="Heatmap",
        )
heatmap.show()

# %% [markdown]
# ## Heatmap - Decision Space - 4 Variables and 4 Objective functions

# %%
data8 = df4[["x1", "x2", "x3", "x4"]].values.tolist()
heatmap_d = px.imshow(
            data8,
            labels={"df4[x1]": "x1", "df4[x2]": "x2", "df4[x3]": "x3", "df4[x4]": "x4"},
            x=["x1", "x2", "x3", "x4"],
            color_continuous_scale=px.colors.sequential.Pinkyl,
            title="Heatmap",
        )
heatmap_d.show()
